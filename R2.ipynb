# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.tsa.arima.model import ARIMA
from pmdarima import auto_arima
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
import os

# 📂 Create a folder for saving results
output_folder = "Retail_Store_2"
os.makedirs(output_folder, exist_ok=True)

# 📌 Load Dataset
file_path = "R2.csv"  # Ensure this is the correct path
data = pd.read_csv(file_path)

# ✅ Convert 'SaleDate' to datetime format
data['SaleDate'] = pd.to_datetime(data['SaleDate'], format='%d/%m/%Y')

# 🔹 Get list of all unique products
products = data['ProductName'].unique()

# 🔄 Loop through all products
for selected_product in products:
    print(f"Processing: {selected_product}...")

    # Extract & process data for the selected product
    product_data = data[data['ProductName'] == selected_product]

    # 📊 Aggregate sales by month
    monthly_sales = product_data.resample('M', on='SaleDate')['QuantitySold'].sum().fillna(0)

    # 🚨 Ensure enough data for training
    if len(monthly_sales) < 24:
        print(f"Skipping {selected_product} due to insufficient data.")
        continue

    train = monthly_sales["2015-01-01":"2023-12-31"]

    # 🔮 Forecast for 60 months (2024-2028)
    forecast_steps = 60
    auto_model = auto_arima(train, seasonal=True, m=12, d=1, D=1, stepwise=True, trace=True)
    best_order = auto_model.order
    best_seasonal_order = auto_model.seasonal_order

    # 🎯 Train ARIMA model
    arima_model = ARIMA(train, order=best_order, seasonal_order=best_seasonal_order)
    arima_results = arima_model.fit()
    arima_forecast = arima_results.forecast(steps=forecast_steps)

    # 🔄 LSTM Model Training & Prediction
    scaler = StandardScaler()

    # ✅ Ensure residuals length match
    min_steps = min(len(train), forecast_steps)
    residuals = arima_forecast.values[:min_steps] - train[-min_steps:].values
    residuals_scaled = scaler.fit_transform(residuals.reshape(-1, 1))

    # ✅ Function to create LSTM sequences
    def create_lstm_data(series, time_steps=3):
        X, y = [], []
        for i in range(len(series) - time_steps):
            X.append(series[i:i + time_steps])
            y.append(series[i + time_steps])
        return np.array(X), np.array(y)

    time_steps = 3
    X_train, y_train = create_lstm_data(residuals_scaled, time_steps)

    # 🚨 Skip if not enough LSTM training samples
    if len(X_train) == 0:
        print(f"Skipping {selected_product} due to insufficient LSTM training samples.")
        continue

    X_train = X_train.reshape((X_train.shape[0], X_train.shape[1], 1))

    # 🤖 Define LSTM Model
    lstm_model = Sequential([
        LSTM(100, activation='relu', return_sequences=True, input_shape=(time_steps, 1)),
        Dropout(0.2),
        LSTM(50, activation='relu'),
        Dropout(0.2),
        Dense(1)
    ])
    lstm_model.compile(optimizer='adam', loss='mse')
    lstm_model.fit(X_train, y_train, epochs=100, batch_size=16, verbose=0)

    # 📈 Make LSTM Predictions
    forecast_steps = min(forecast_steps, len(X_train))
    lstm_pred = lstm_model.predict(X_train[-forecast_steps:].reshape((forecast_steps, time_steps, 1))).flatten()
    lstm_pred = scaler.inverse_transform(lstm_pred.reshape(-1, 1)).flatten()
    final_forecast = 0.95 * arima_forecast[:forecast_steps] + 0.05 * lstm_pred
    final_forecast = np.maximum(1, np.round(final_forecast)).astype(int)

    # 🗓️ Create Forecast Dates
    forecast_dates = pd.date_range(start=monthly_sales.index[-1], periods=forecast_steps + 1, freq='M')[1:]

    # ✅ Save forecasted sales
    forecast_file = f"{output_folder}/{selected_product}_forecast_2024_2028.csv"
    pd.DataFrame({'Date': forecast_dates, 'Predicted Sales': final_forecast}).to_csv(forecast_file, index=False)

    print(f"✅ Forecasting completed for {selected_product}!")
    print(f"📂 Results saved in: {forecast_file}")

    # 📊 **Plot Historical & Forecasted Sales**
    plt.figure(figsize=(14, 7))
    plt.plot(monthly_sales.index, monthly_sales.values, label="Actual Sales (2015-2023)", marker="o", color="blue")
    plt.plot(forecast_dates, final_forecast, label="Predicted Sales (2024-2028)", marker="o", linestyle="--", color="red")

    # Ensure continuity between actual sales and forecast
    plt.plot([monthly_sales.index[-1], forecast_dates[0]], [monthly_sales.values[-1], final_forecast[0]], linestyle="--", color="red")

    plt.title(f"Total Sales + Forecast for {selected_product}")
    plt.xlabel("Date")
    plt.ylabel("Quantity Sold")
    plt.legend()
    plt.grid(True)

    # ✅ Save the updated plot
    plot_file_combined = f"{output_folder}/{selected_product}_forecast_plot.png"
    plt.savefig(plot_file_combined, dpi=300, bbox_inches="tight")

    print(f"📊 Combined sales plot saved as: {plot_file_combined}")

    # ✅ Show the updated plot
    plt.show()
# Out:
# Processing: Nanoleaf Shapes Smart Light Panels...
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(1,1,1)[12]             : AIC=inf, Time=5.69 sec
#  ARIMA(0,1,0)(0,1,0)[12]             : AIC=1181.849, Time=0.03 sec
#  ARIMA(1,1,0)(1,1,0)[12]             : AIC=1139.843, Time=1.04 sec
#  ARIMA(0,1,1)(0,1,1)[12]             : AIC=1098.580, Time=0.91 sec
#  ARIMA(0,1,1)(0,1,0)[12]             : AIC=inf, Time=0.55 sec
#  ARIMA(0,1,1)(1,1,1)[12]             : AIC=inf, Time=1.36 sec
#  ARIMA(0,1,1)(0,1,2)[12]             : AIC=inf, Time=3.83 sec
#  ARIMA(0,1,1)(1,1,0)[12]             : AIC=1109.012, Time=1.09 sec
#  ARIMA(0,1,1)(1,1,2)[12]             : AIC=inf, Time=3.18 sec
#  ARIMA(0,1,0)(0,1,1)[12]             : AIC=inf, Time=0.15 sec
#  ARIMA(1,1,1)(0,1,1)[12]             : AIC=inf, Time=0.55 sec
#  ARIMA(0,1,2)(0,1,1)[12]             : AIC=inf, Time=0.44 sec
#  ARIMA(1,1,0)(0,1,1)[12]             : AIC=1129.435, Time=0.36 sec
#  ARIMA(1,1,2)(0,1,1)[12]             : AIC=1100.826, Time=0.95 sec
#  ARIMA(0,1,1)(0,1,1)[12] intercept   : AIC=inf, Time=0.52 sec
#
# Best model:  ARIMA(0,1,1)(0,1,1)[12]
# Total fit time: 20.655 seconds
# c:\Users\yasee\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\rnn\rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 681ms/step
# ✅ Forecasting completed for Nanoleaf Shapes Smart Light Panels!
# 📂 Results saved in: Retail_Store_2/Nanoleaf Shapes Smart Light Panels_forecast_2024_2028.csv
# 📊 Combined sales plot saved as: Retail_Store_2/Nanoleaf Shapes Smart Light Panels_forecast_plot.png
# Processing: Insta360 X3 Action Camera...
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(1,1,1)[12]             : AIC=inf, Time=5.92 sec
#  ARIMA(0,1,0)(0,1,0)[12]             : AIC=1213.619, Time=0.01 sec
#  ARIMA(1,1,0)(1,1,0)[12]             : AIC=1169.018, Time=0.24 sec
#  ARIMA(0,1,1)(0,1,1)[12]             : AIC=inf, Time=1.70 sec
#  ARIMA(1,1,0)(0,1,0)[12]             : AIC=1208.695, Time=0.05 sec
#  ARIMA(1,1,0)(2,1,0)[12]             : AIC=1166.858, Time=3.06 sec
#  ARIMA(1,1,0)(2,1,1)[12]             : AIC=1161.538, Time=10.79 sec
#  ARIMA(1,1,0)(1,1,1)[12]             : AIC=1159.856, Time=2.39 sec
#  ARIMA(1,1,0)(0,1,1)[12]             : AIC=inf, Time=2.07 sec
#  ARIMA(1,1,0)(1,1,2)[12]             : AIC=inf, Time=19.45 sec
#  ARIMA(1,1,0)(0,1,2)[12]             : AIC=1160.418, Time=9.13 sec
#  ARIMA(1,1,0)(2,1,2)[12]             : AIC=inf, Time=12.23 sec
#  ARIMA(0,1,0)(1,1,1)[12]             : AIC=1169.525, Time=0.68 sec
#  ARIMA(2,1,0)(1,1,1)[12]             : AIC=1156.927, Time=3.27 sec
#  ARIMA(2,1,0)(0,1,1)[12]             : AIC=inf, Time=2.40 sec
#  ARIMA(2,1,0)(1,1,0)[12]             : AIC=1166.264, Time=0.36 sec
#  ARIMA(2,1,0)(2,1,1)[12]             : AIC=1158.774, Time=5.29 sec
#  ARIMA(2,1,0)(1,1,2)[12]             : AIC=inf, Time=6.21 sec
#  ARIMA(2,1,0)(0,1,0)[12]             : AIC=1200.518, Time=0.23 sec
#  ARIMA(2,1,0)(0,1,2)[12]             : AIC=1157.217, Time=8.70 sec
#  ARIMA(2,1,0)(2,1,0)[12]             : AIC=1163.616, Time=2.42 sec
#  ARIMA(2,1,0)(2,1,2)[12]             : AIC=inf, Time=5.14 sec
#  ARIMA(3,1,0)(1,1,1)[12]             : AIC=1154.285, Time=0.92 sec
#  ARIMA(3,1,0)(0,1,1)[12]             : AIC=inf, Time=2.58 sec
#  ARIMA(3,1,0)(1,1,0)[12]             : AIC=1163.375, Time=1.75 sec
#  ARIMA(3,1,0)(2,1,1)[12]             : AIC=1155.952, Time=2.71 sec
#  ARIMA(3,1,0)(1,1,2)[12]             : AIC=inf, Time=6.22 sec
#  ARIMA(3,1,0)(0,1,0)[12]             : AIC=1199.944, Time=0.31 sec
#  ARIMA(3,1,0)(0,1,2)[12]             : AIC=1154.771, Time=2.83 sec
#  ARIMA(3,1,0)(2,1,0)[12]             : AIC=1161.173, Time=174.12 sec
#  ARIMA(3,1,0)(2,1,2)[12]             : AIC=1157.140, Time=32.38 sec
#  ARIMA(4,1,0)(1,1,1)[12]             : AIC=1145.334, Time=3.94 sec
#  ARIMA(4,1,0)(0,1,1)[12]             : AIC=inf, Time=7.21 sec
#  ARIMA(4,1,0)(1,1,0)[12]             : AIC=1152.515, Time=3.61 sec
#  ARIMA(4,1,0)(2,1,1)[12]             : AIC=1146.323, Time=18.12 sec
#  ARIMA(4,1,0)(1,1,2)[12]             : AIC=1145.865, Time=19.91 sec
#  ARIMA(4,1,0)(0,1,0)[12]             : AIC=1197.520, Time=0.52 sec
#  ARIMA(4,1,0)(0,1,2)[12]             : AIC=1147.204, Time=16.35 sec
#  ARIMA(4,1,0)(2,1,0)[12]             : AIC=1150.994, Time=7.02 sec
#  ARIMA(4,1,0)(2,1,2)[12]             : AIC=1147.877, Time=33.17 sec
#  ARIMA(5,1,0)(1,1,1)[12]             : AIC
sec
#  ARIMA(5,1,0)(2,1,1)[12]             : AIC=1065.810, Time=3.48 sec
#  ARIMA(5,1,0)(1,1,1)[12]             : AIC=inf, Time=0.86 sec
#  ARIMA(5,1,0)(2,1,0)[12]             : AIC=1075.225, Time=0.48 sec
#  ARIMA(5,1,0)(2,1,2)[12]             : AIC=inf, Time=2.20 sec
#  ARIMA(5,1,0)(1,1,0)[12]             : AIC=1084.355, Time=0.21 sec
#  ARIMA(5,1,0)(1,1,2)[12]             : AIC=inf, Time=5.07 sec
#  ARIMA(5,1,1)(2,1,1)[12]             : AIC=inf, Time=2.96 sec
#  ARIMA(4,1,1)(2,1,1)[12]             : AIC=1061.236, Time=1.18 sec
#  ARIMA(4,1,1)(1,1,1)[12]             : AIC=inf, Time=1.52 sec
#  ARIMA(4,1,1)(2,1,0)[12]             : AIC=inf, Time=0.74 sec
#  ARIMA(4,1,1)(2,1,2)[12]             : AIC=inf, Time=5.68 sec
#  ARIMA(4,1,1)(1,1,0)[12]             : AIC=inf, Time=2.39 sec
#  ARIMA(4,1,1)(1,1,2)[12]             : AIC=inf, Time=2.03 sec
#  ARIMA(3,1,1)(2,1,1)[12]             : AIC=1059.842, Time=2.95 sec
#  ARIMA(3,1,1)(1,1,1)[12]             : AIC=inf, Time=0.97 sec
#  ARIMA(3,1,1)(2,1,0)[12]             : AIC=inf, Time=0.62 sec
#  ARIMA(3,1,1)(2,1,2)[12]             : AIC=inf, Time=2.28 sec
#  ARIMA(3,1,1)(1,1,0)[12]             : AIC=1080.950, Time=0.62 sec
#  ARIMA(3,1,1)(1,1,2)[12]             : AIC=inf, Time=1.43 sec
#  ARIMA(2,1,1)(2,1,1)[12]             : AIC=inf, Time=0.90 sec
#  ARIMA(3,1,2)(2,1,1)[12]             : AIC=inf, Time=3.27 sec
#  ARIMA(2,1,2)(2,1,1)[12]             : AIC=inf, Time=1.38 sec
#  ARIMA(4,1,2)(2,1,1)[12]             : AIC=inf, Time=2.87 sec
#  ARIMA(3,1,1)(2,1,1)[12] intercept   : AIC=1061.765, Time=1.46 sec
#
# Best model:  ARIMA(3,1,1)(2,1,1)[12]
# Total fit time: 94.674 seconds
# c:\Users\yasee\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\rnn\rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 357ms/step
# ✅ Forecasting completed for De'Longhi Dinamica Espresso Machine!
# 📂 Results saved in: Retail_Store_2/De'Longhi Dinamica Espresso Machine_forecast_2024_2028.csv
# 📊 Combined sales plot saved as: Retail_Store_2/De'Longhi Dinamica Espresso Machine_forecast_plot.png
# Processing: Valve Steam Deck Handheld...
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(1,1,1)[12]             : AIC=inf, Time=3.45 sec
#  ARIMA(0,1,0)(0,1,0)[12]             : AIC=1167.756, Time=0.02 sec
#  ARIMA(1,1,0)(1,1,0)[12]             : AIC=1125.806, Time=0.19 sec
#  ARIMA(0,1,1)(0,1,1)[12]             : AIC=inf, Time=0.31 sec
#  ARIMA(1,1,0)(0,1,0)[12]             : AIC=1146.669, Time=0.03 sec
#  ARIMA(1,1,0)(2,1,0)[12]             : AIC=1112.330, Time=0.27 sec
#  ARIMA(1,1,0)(2,1,1)[12]             : AIC=1103.867, Time=2.94 sec
#  ARIMA(1,1,0)(1,1,1)[12]             : AIC=inf, Time=0.24 sec
#  ARIMA(1,1,0)(2,1,2)[12]             : AIC=inf, Time=1.88 sec
#  ARIMA(1,1,0)(1,1,2)[12]             : AIC=inf, Time=1.13 sec
#  ARIMA(0,1,0)(2,1,1)[12]             : AIC=1128.314, Time=0.59 sec
#  ARIMA(2,1,0)(2,1,1)[12]             : AIC=1096.772, Time=1.51 sec
#  ARIMA(2,1,0)(1,1,1)[12]             : AIC=inf, Time=0.33 sec
#  ARIMA(2,1,0)(2,1,0)[12]             : AIC=1104.596, Time=0.31 sec
#  ARIMA(2,1,0)(2,1,2)[12]             : AIC=inf, Time=1.83 sec
#  ARIMA(2,1,0)(1,1,0)[12]             : AIC=1118.895, Time=0.16 sec
#  ARIMA(2,1,0)(1,1,2)[12]             : AIC=inf, Time=1.37 sec
#  ARIMA(3,1,0)(2,1,1)[12]             : AIC=1095.298, Time=1.50 sec
#  ARIMA(3,1,0)(1,1,1)[12]             : AIC=inf, Time=0.82 sec
#  ARIMA(3,1,0)(2,1,0)[12]             : AIC=1103.842, Time=0.38 sec
#  ARIMA(3,1,0)(2,1,2)[12]             : AIC=inf, Time=2.15 sec
#  ARIMA(3,1,0)(1,1,0)[12]             : AIC=1118.797, Time=0.21 sec
#  ARIMA(3,1,0)(1,1,2)[12]             : AIC=inf, Time=1.06 sec
#  ARIMA(4,1,0)(2,1,1)[12]             : AIC=1084.825, Time=1.49 sec
#  ARIMA(4,1,0)(1,1,1)[12]             : AIC=inf, Time=0.50 sec
#  ARIMA(4,1,0)(2,1,0)[12]             : AIC=1095.212, Time=0.50 sec
#  ARIMA(4,1,0)(2,1,2)[12]             : AIC=1085.123, Time=5.41 sec
#  ARIMA(4,1,0)(1,1,0)[12]             : AIC=1109.947, Time=0.56 sec
#  ARIMA(4,1,0)(1,1,2)[12]             : AIC=inf, Time=3.22 sec
#  ARIMA(5,1,0)(2,1,1)[12]             : AIC=1082.583, Time=5.14 sec
#  ARIMA(5,1,0)(1,1,1)[12]             : AIC=inf, Time=1.92 sec
#  ARIMA(5,1,0)(2,1,0)[12]             : AIC=1092.679, Time=0.61 sec
#  ARIMA(5,1,0)(2,1,2)[12]             : AIC=1083.627, Time=2.68 sec
#  ARIMA(5,1,0)(1,1,0)[12]             : AIC=1107.331, Time=0.27 sec
#  ARIMA(5,1,0)(1,1,2)[12]             : AIC=inf, Time=3.60 sec
#  ARIMA(5,1,1)(2,1,1)[12]             : AIC=inf, Time=3.81 sec
#  ARIMA(4,1,1)(2,1,1)[12]             : AIC=inf, Time=6.64 sec
#  ARIMA(5,1,0)(2,1,1)[12] intercept   : AIC=1084.584, Time=5.53 sec
#
# Best model:  ARIMA(5,1,0)(2,1,1)[12]
# Total fit time: 64.599 seconds
# c:\Users\yasee\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\rnn\rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 469ms/step
# ✅ Forecasting completed for Valve Steam Deck Handheld!
# 📂 Results saved in: Retail_Store_2/Valve Steam Deck Handheld_forecast_2024_2028.csv
# 📊 Combined sales plot saved as: Retail_Store_2/Valve Steam Deck Handheld_forecast_plot.png
# Processing: Garmin Forerunner 965...
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(1,1,1)[12]             : AIC=inf, Time=6.13 sec
#  ARIMA(0,1,0)(0,1,0)[12]             : AIC=1173.610, Time=0.03 sec
#  ARIMA(1,1,0)(1,1,0)[12]             : AIC=1123.511, Time=1.17 sec
#  ARIMA(0,1,1)(0,1,1)[12]             : AIC=inf, Time=1.70 sec
#  ARIMA(1,1,0)(0,1,0)[12]             : AIC=1152.770, Time=0.04 sec
#  ARIMA(1,1,0)(2,1,0)[12]             : AIC=1112.256, Time=0.81 sec
#  ARIMA(1,1,0)(2,1,1)[12]             : AIC=inf, Time=9.19 sec
#  ARIMA(1,1,0)(1,1,1)[12]             : AIC=inf, Time=1.75 sec
#  ARIMA(0,1,0)(2,1,0)[12]             : AIC=1129.141, Time=0.77 sec
#  ARIMA(2,1,0)(2,1,0)[12]             : AIC=1083.389, Time=0.43 sec
#  ARIMA(2,1,0)(1,1,0)[12]             : AIC=1098.432, Time=0.17 sec
#  ARIMA(2,1,0)(2,1,1)[12]             : AIC=inf, Time=1.56 sec
#  ARIMA(2,1,0)(1,1,1)[12]             : AIC=inf, Time=0.34 sec
#  ARIMA(3,1,0)(2,1,0)[12]             : AIC=1077.787, Time=0.48 sec
#  ARIMA(3,1,0)(1,1,0)[12]             : AIC=1094.835, Time=0.17 sec
#  ARIMA(3,1,0)(2,1,1)[12]             : AIC=1077.656, Time=1.01 sec
#  ARIMA(3,1,0)(1,1,1)[12]             : AIC=inf, Time=0.61 sec
#  ARIMA(3,1,0)(2,1,2)[12]             : AIC=inf, Time=1.45 sec
#  ARIMA(3,1,0)(1,1,2)[12]             : AIC=inf, Time=3.64 sec
#  ARIMA(4,1,0)(2,1,1)[12]             : AIC=inf, Time=1.86 sec
#  ARIMA(3,1,1)(2,1,1)[12]             : AIC=inf, Time=1.81 sec
#  ARIMA(2,1,1)(2,1,1)[12]             : AIC=1066.459, Time=1.83 sec
#  ARIMA(2,1,1)(1,1,1)[12]             : AIC=inf, Time=0.50 sec
#  ARIMA(2,1,1)(2,1,0)[12]             : AIC=1068.217, Time=0.84 sec
#  ARIMA(2,1,1)(2,1,2)[12]             : AIC=inf, Time=3.49 sec
#  ARIMA(2,1,1)(1,1,0)[12]             : AIC=1081.927, Time=0.61 sec
#  ARIMA(2,1,1)(1,1,2)[12]             : AIC=inf, Time=1.81 sec
#  ARIMA(1,1,1)(2,1,1)[12]             : AIC=1069.094, Time=0.79 sec
#  ARIMA(2,1,2)(2,1,1)[12]             : AIC=inf, Time=2.05 sec
#  ARIMA(1,1,2)(2,1,1)[12]             : AIC=inf, Time=1.15 sec
#  ARIMA(3,1,2)(2,1,1)[12]             : AIC=1070.128, Time=3.40 sec
#  ARIMA(2,1,1)(2,1,1)[12] intercept   : AIC=inf, Time=1.89 sec
#
# Best model:  ARIMA(2,1,1)(2,1,1)[12]
# Total fit time: 53.500 seconds
# c:\Users\yasee\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\rnn\rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 333ms/step
# ✅ Forecasting completed for Garmin Forerunner 965!
# 📂 Results saved in: Retail_Store_2/Garmin Forerunner 965_forecast_2024_2028.csv
# 📊 Combined sales plot saved as: Retail_Store_2/Garmin Forerunner 965_forecast_plot.png
# Processing: Shark FlexStyle Air Styling System...
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(1,1,1)[12]             : AIC=inf, Time=0.70 sec
#  ARIMA(0,1,0)(0,1,0)[12]             : AIC=1211.525, Time=0.01 sec
#  ARIMA(1,1,0)(1,1,0)[12]             : AIC=1161.419, Time=0.09 sec
#  ARIMA(0,1,1)(0,1,1)[12]             : AIC=1127.253, Time=0.75 sec
#  ARIMA(0,1,1)(0,1,0)[12]             : AIC=inf, Time=0.35 sec
#  ARIMA(0,1,1)(1,1,1)[12]             : AIC=inf, Time=1.11 sec
#  ARIMA(0,1,1)(0,1,2)[12]             : AIC=inf, Time=1.70 sec
#  ARIMA(0,1,1)(1,1,0)[12]             : AIC=1135.091, Time=0.26 sec
#  ARIMA(0,1,1)(1,1,2)[12]             : AIC=inf, Time=2.27 sec
#  ARIMA(0,1,0)(0,1,1)[12]             : AIC=1177.975, Time=0.11 sec
#  ARIMA(1,1,1)(0,1,1)[12]             : AIC=inf, Time=1.03 sec
#  ARIMA(0,1,2)(0,1,1)[12]             : AIC=inf, Time=1.67 sec
#  ARIMA(1,1,0)(0,1,1)[12]             : AIC=1152.543, Time=0.23 sec
#  ARIMA(1,1,2)(0,1,1)[12]             : AIC=1130.873, Time=2.74 sec
#  ARIMA(0,1,1)(0,1,1)[12] intercept   : AIC=inf, Time=1.68 sec
#
# Best model:  ARIMA(0,1,1)(0,1,1)[12]
# Total fit time: 14.725 seconds
# c:\Users\yasee\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\rnn\rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 329ms/step
# ✅ Forecasting completed for Shark FlexStyle Air Styling System!
# 📂 Results saved in: Retail_Store_2/Shark FlexStyle Air Styling System_forecast_2024_2028.csv
# 📊 Combined sales plot saved as: Retail_Store_2/Shark FlexStyle Air Styling System_forecast_plot.png
# Processing: Acer Swift Edge 16 Laptop...
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(1,1,1)[12]             : AIC=inf, Time=0.90 sec
#  ARIMA(0,1,0)(0,1,0)[12]             : AIC=1145.041, Time=0.02 sec
#  ARIMA(1,1,0)(1,1,0)[12]             : AIC=1081.169, Time=0.12 sec
#  ARIMA(0,1,1)(0,1,1)[12]             : AIC=inf, Time=0.79 sec
#  ARIMA(1,1,0)(0,1,0)[12]             : AIC=1112.131, Time=0.05 sec
#  ARIMA(1,1,0)(2,1,0)[12]             : AIC=1075.620, Time=1.56 sec
#  ARIMA(1,1,0)(2,1,1)[12]             : AIC=inf, Time=0.53 sec
#  ARIMA(1,1,0)(1,1,1)[12]             : AIC=inf, Time=0.17 sec
#  ARIMA(0,1,0)(2,1,0)[12]             : AIC=1113.479, Time=0.21 sec
#  ARIMA(2,1,0)(2,1,0)[12]             : AIC=1067.917, Time=0.27 sec
#  ARIMA(2,1,0)(1,1,0)[12]             : AIC=1073.344, Time=0.29 sec
#  ARIMA(2,1,0)(2,1,1)[12]             : AIC=inf, Time=2.93 sec
#  ARIMA(2,1,0)(1,1,1)[12]             : AIC=1059.595, Time=0.59 sec
#  ARIMA(2,1,0)(0,1,1)[12]             : AIC=inf, Time=0.16 sec
#  ARIMA(2,1,0)(1,1,2)[12]             : AIC=inf, Time=2.29 sec
#  ARIMA(2,1,0)(0,1,0)[12]             : AIC=1105.634, Time=0.07 sec
#  ARIMA(2,1,0)(0,1,2)[12]             : AIC=1059.629, Time=1.01 sec
#  ARIMA(2,1,0)(2,1,2)[12]             : AIC=inf, Time=1.23 sec
#  ARIMA(3,1,0)(1,1,1)[12]             : AIC=inf, Time=0.65 sec
#  ARIMA(2,1,1)(1,1,1)[12]             : AIC=inf, Time=0.66 sec
#  ARIMA(1,1,1)(1,1,1)[12]             : AIC=inf, Time=0.52 sec
#  ARIMA(3,1,1)(1,1,1)[12]             : AIC=inf, Time=3.41 sec
#  ARIMA(2,1,0)(1,1,1)[12] intercept   : AIC=1061.594, Time=0.72 sec
#
# Best model:  ARIMA(2,1,0)(1,1,1)[12]
# Total fit time: 19.145 seconds
# c:\Users\yasee\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\rnn\rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 963ms/step
# ✅ Forecasting completed for Acer Swift Edge 16 Laptop!
# 📂 Results saved in: Retail_Store_2/Acer Swift Edge 16 Laptop_forecast_2024_2028.csv
# 📊 Combined sales plot saved as: Retail_Store_2/
sec
#  ARIMA(4,1,0)(2,1,1)[12]             : AIC=1024.525, Time=3.69 sec
#  ARIMA(4,1,0)(1,1,1)[12]             : AIC=inf, Time=0.31 sec
#  ARIMA(4,1,0)(2,1,0)[12]             : AIC=1031.187, Time=0.40 sec
#  ARIMA(4,1,0)(1,1,0)[12]             : AIC=1046.027, Time=0.31 sec
#  ARIMA(5,1,0)(2,1,1)[12]             : AIC=1025.006, Time=2.50 sec
#  ARIMA(4,1,1)(2,1,1)[12]             : AIC=inf, Time=0.90 sec
#  ARIMA(3,1,1)(2,1,1)[12]             : AIC=inf, Time=0.90 sec
#  ARIMA(5,1,1)(2,1,1)[12]             : AIC=inf, Time=1.02 sec
#  ARIMA(4,1,0)(2,1,1)[12] intercept   : AIC=1026.482, Time=5.53 sec
#
# Best model:  ARIMA(4,1,0)(2,1,1)[12]
# Total fit time: 33.098 seconds
# c:\Users\yasee\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\rnn\rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 376ms/step
# ✅ Forecasting completed for Honeywell Home T9 Smart Thermostat!
# 📂 Results saved in: Retail_Store_2/Honeywell Home T9 Smart Thermostat_forecast_2024_2028.csv
# 📊 Combined sales plot saved as: Retail_Store_2/Honeywell Home T9 Smart Thermostat_forecast_plot.png
# Processing: Roborock S7 MaxV Ultra Vacuum...
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(1,1,1)[12]             : AIC=inf, Time=1.98 sec
#  ARIMA(0,1,0)(0,1,0)[12]             : AIC=1155.636, Time=0.04 sec
#  ARIMA(1,1,0)(1,1,0)[12]             : AIC=1121.046, Time=0.93 sec
#  ARIMA(0,1,1)(0,1,1)[12]             : AIC=inf, Time=0.97 sec
#  ARIMA(1,1,0)(0,1,0)[12]             : AIC=1142.004, Time=0.04 sec
#  ARIMA(1,1,0)(2,1,0)[12]             : AIC=1117.709, Time=0.33 sec
#  ARIMA(1,1,0)(2,1,1)[12]             : AIC=inf, Time=0.51 sec
#  ARIMA(1,1,0)(1,1,1)[12]             : AIC=inf, Time=0.24 sec
#  ARIMA(0,1,0)(2,1,0)[12]             : AIC=1129.256, Time=0.17 sec
#  ARIMA(2,1,0)(2,1,0)[12]             : AIC=1111.317, Time=1.53 sec
#  ARIMA(2,1,0)(1,1,0)[12]             : AIC=1114.555, Time=0.22 sec
#  ARIMA(2,1,0)(2,1,1)[12]             : AIC=inf, Time=5.37 sec
#  ARIMA(2,1,0)(1,1,1)[12]             : AIC=inf, Time=3.41 sec
#  ARIMA(3,1,0)(2,1,0)[12]             : AIC=1111.619, Time=0.69 sec
#  ARIMA(2,1,1)(2,1,0)[12]             : AIC=inf, Time=4.82 sec
#  ARIMA(1,1,1)(2,1,0)[12]             : AIC=inf, Time=0.57 sec
#  ARIMA(3,1,1)(2,1,0)[12]             : AIC=inf, Time=1.81 sec
#  ARIMA(2,1,0)(2,1,0)[12] intercept   : AIC=1113.284, Time=0.56 sec
#
# Best model:  ARIMA(2,1,0)(2,1,0)[12]
# Total fit time: 24.200 seconds
# c:\Users\yasee\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\rnn\rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# ...
#  ARIMA(2,1,0)(2,1,0)[12]             : AIC=383.459, Time=0.68 sec
#  ARIMA(2,1,0)(1,1,0)[12]             : AIC=387.340, Time=0.14 sec
#  ARIMA(2,1,0)(2,1,1)[12]             : AIC=inf, Time=0.70 sec
#  ARIMA(2,1,0)(1,1,1)[12]             : AIC=inf, Time=0.35 sec
#  ARIMA(3,1,0)(2,1,0)[12]             : AIC=381.994, Time=0.18 sec
#  ARIMA(3,1,0)(1,1,0)[12]             : AIC=384.566, Time=0.11 sec
#  ARIMA(3,1,0)(2,1,1)[12]             : AIC=inf, Time=1.13 sec
#  ARIMA(3,1,0)(1,1,1)[12]             : AIC=inf, Time=0.97 sec
#  ARIMA(4,1,0)(2,1,0)[12]             : AIC=381.398, Time=0.22 sec
#  ARIMA(4,1,0)(1,1,0)[12]             : AIC=383.323, Time=0.17 sec
#  ARIMA(4,1,0)(2,1,1)[12]             : AIC=inf, Time=4.03 sec
#  ARIMA(4,1,0)(1,1,1)[12]             : AIC=inf, Time=2.16 sec
#  ARIMA(5,1,0)(2,1,0)[12]             : AIC=381.605, Time=0.46 sec
#  ARIMA(4,1,1)(2,1,0)[12]             : AIC=inf, Time=1.76 sec
#  ARIMA(3,1,1)(2,1,0)[12]             : AIC=inf, Time=1.03 sec
#  ARIMA(5,1,1)(2,1,0)[12]             : AIC=inf, Time=6.78 sec
#  ARIMA(4,1,0)(2,1,0)[12] intercept   : AIC=383.245, Time=4.01 sec
#
# Best model:  ARIMA(4,1,0)(2,1,0)[12]
# Total fit time: 31.316 seconds
# c:\Users\yasee\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\rnn\rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 352ms/step
# ✅ Forecasting completed for War and Peace!
# 📂 Results saved in: Retail_Store_2/War and Peace_forecast_2024_2028.csv
# 📊 Combined sales plot saved as: Retail_Store_2/War and Peace_forecast_plot.png
# Processing: Fahrenheit 451...
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(1,1,1)[12]             : AIC=inf, Time=1.01 sec
#  ARIMA(0,1,0)(0,1,0)[12]             : AIC=537.245, Time=0.01 sec
#  ARIMA(1,1,0)(1,1,0)[12]             : AIC=500.426, Time=0.08 sec
#  ARIMA(0,1,1)(0,1,1)[12]             : AIC=inf, Time=2.71 sec
#  ARIMA(1,1,0)(0,1,0)[12]             : AIC=533.933, Time=0.02 sec
#  ARIMA(1,1,0)(2,1,0)[12]             : AIC=498.268, Time=1.05 sec
#  ARIMA(1,1,0)(2,1,1)[12]             : AIC=inf, Time=2.19 sec
#  ARIMA(1,1,0)(1,1,1)[12]             : AIC=inf, Time=1.38 sec
#  ARIMA(0,1,0)(2,1,0)[12]             : AIC=501.435, Time=0.92 sec
#  ARIMA(2,1,0)(2,1,0)[12]             : AIC=493.991, Time=1.18 sec
#  ARIMA(2,1,0)(1,1,0)[12]             : AIC=496.907, Time=0.68 sec
#  ARIMA(2,1,0)(2,1,1)[12]             : AIC=inf, Time=8.72 sec
#  ARIMA(2,1,0)(1,1,1)[12]             : AIC=inf, Time=3.42 sec
#  ARIMA(3,1,0)(2,1,0)[12]             : AIC=487.930, Time=0.51 sec
#  ARIMA(3,1,0)(1,1,0)[12]             : AIC=490.411, Time=0.22 sec
#  ARIMA(3,1,0)(2,1,1)[12]             : AIC=inf, Time=4.01 sec
#  ARIMA(3,1,0)(1,1,1)[12]             : AIC=inf, Time=0.80 sec
#  ARIMA(4,1,0)(2,1,0)[12]             : AIC=489.394, Time=0.32 sec
#  ARIMA(3,1,1)(2,1,0)[12]             : AIC=inf, Time=4.13 sec
#  ARIMA(2,1,1)(2,1,0)[12]             : AIC=inf, Time=1.90 sec
#  ARIMA(4,1,1)(2,1,0)[12]             : AIC=inf, Time=1.84 sec
#  ARIMA(3,1,0)(2,1,0)[12] intercept   : AIC=489.671, Time=0.55 sec
#
# Best model:  ARIMA(3,1,0)(2,1,0)[12]
# Total fit time: 37.724 seconds
# c:\Users\yasee\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\rnn\rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 472ms/step
# ✅ Forecasting completed for Fahrenheit 451!
# 📂 Results saved in: Retail_Store_2/Fahrenheit 451_forecast_2024_2028.csv
# 📊 Combined sales plot saved as: Retail_Store_2/Fahrenheit 451_forecast_plot.png
# Processing: Under Armour HeatGear Compression Shirt...
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(1,1,1)[12]             : AIC=360.128, Time=4.03 sec
#  ARIMA(0,1,0)(0,1,0)[12]             : AIC=392.703, Time=0.02 sec
#  ARIMA(1,1,0)(1,1,0)[12]             : AIC=373.409, Time=0.56 sec
#  ARIMA(0,1,1)(0,1,1)[12]             : AIC=352.138, Time=0.64 sec
#  ARIMA(0,1,1)(0,1,0)[12]             : AIC=351.695, Time=0.31 sec
#  ARIMA(0,1,1)(1,1,0)[12]             : AIC=352.160, Time=0.45 sec
#  ARIMA(0,1,1)(1,1,1)[12]             : AIC=354.138, Time=0.95 sec
#  ARIMA(1,1,1)(0,1,0)[12]             : AIC=353.656, Time=0.20 sec
#  ARIMA(0,1,2)(0,1,0)[12]             : AIC=353.656, Time=0.22 sec
#  ARIMA(1,1,0)(0,1,0)[12]             : AIC=373.071, Time=0.03 sec
#  ARIMA(1,1,2)(0,1,0)[12]             : AIC=355.627, Time=0.11 sec
#  ARIMA(0,1,1)(0,1,0)[12] intercept   : AIC=inf, Time=0.35 sec
#
# Best model:  ARIMA(0,1,1)(0,1,0)[12]
# Total fit time: 7.873 seconds
# c:\Users\yasee\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\rnn\rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 544ms/step
# ✅ Forecasting completed for Under Armour HeatGear Compression Shirt!
# 📂 Results saved in: Retail_Store_2/Under Armour HeatGear Compression Shirt_forecast_2024_2028.csv
# 📊 Combined sales plot saved as: Retail_Store_2/Under Armour HeatGear Compression Shirt_forecast_plot.png
# Processing: The Great Gatsby...
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(1,1,1)[12]             : AIC=inf, Time=3.97 sec
#  ARIMA(0,1,0)(0,1,0)[12]             : AIC=322.335, Time=0.01 sec
#  ARIMA(1,1,0)(1,1,0)[12]             : AIC=299.814, Time=0.09 sec
#  ARIMA(0,1,1)(0,1,1)[12]             : AIC=288.242, Time=0.07 sec
#  ARIMA(0,1,1)(0,1,0)[12]             : AIC=291.738, Time=0.07 sec
#  ARIMA(0,1,1)(1,1,1)[12]             : AIC=289.750, Time=0.44 sec
#  ARIMA(0,1,1)(0,1,2)[12]             : AIC=289.753, Time=3.17 sec
#  ARIMA(0,1,1)(1,1,0)[12]             : AIC=288.031, Time=0.40 sec
#  ARIMA(0,1,1)(2,1,0)[12]             : AIC=289.736, Time=0.22 sec
#  ARIMA(0,1,1)(2,1,1)[12]             : AIC=291.735, Time=0.56 sec
#  ARIMA(0,1,0)(1,1,0)[12]             : AIC=312.283, Time=0.06 sec
#  ARIMA(1,1,1)(1,1,0)[12]             : AIC=288.062, Time=0.18 sec
#  ARIMA(0,1,2)(1,1,0)[12]             : AIC=287.646, Time=0.12 sec
#  ARIMA(0,1,2)(0,1,0)[12]             : AIC=289.693, Time=0.08 sec
#  ARIMA(0,1,2)(2,1,0)[12]             : AIC=289.623, Time=3.71 sec
#  ARIMA(0,1,2)(1,1,1)[12]             : AIC=289.627, Time=0.26 sec
#  ARIMA(0,1,2)(0,1,1)[12]             : AIC=288.062, Time=0.13 sec
#  ARIMA(0,1,2)(2,1,1)[12]             : AIC=inf, Time=1.01 sec
#  ARIMA(1,1,2)(1,1,0)[12]             : AIC=inf, Time=2.60 sec
#  ARIMA(0,1,3)(1,1,0)[12]             : AIC=289.467, Time=1.03 sec
#  ARIMA(1,1,3)(1,1,0)[12]             : AIC=inf, Time=1.26 sec
#  ARIMA(0,1,2)(1,1,0)[12] intercept   : AIC=inf, Time=0.63 sec
#
# Best model:  ARIMA(0,1,2)(1,1,0)[12]
# Total fit time: 20.092 seconds
# c:\Users\yasee\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:997: UserWarning: Non-stationary starting seasonal autoregressive Using zeros as starting parameters.
#   warn('Non-stationary starting seasonal autoregressive'
# c:\Users\yasee\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\rnn\rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 602ms/step
# ✅ Forecasting completed for The Great Gatsby!
# 📂 Results saved in: Retail_Store_2/The Great Gatsby_forecast_2024_2028.csv
# 📊 Combined sales plot saved as: Retail_Store_2/The Great Gatsby_forecast_plot.png
# Processing: Nike Dri-FIT Running Shorts...
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(1,1,1)[12]             : AIC=509.446, Time=1.79 sec
#  ARIMA(0,1,0)(0,1,0)[12]             : AIC=569.068, Time=0.02 sec
#  ARIMA(1,1,0)(1,1,0)[12]             : AIC=535.447, Time=0.33 sec
#  ARIMA(0,1,1)(0,1,1)[12]             : AIC=504.037, Time=0.19 sec
#  ARIMA(0,1,1)(0,1,0)[12]             : AIC=516.142, Time=0.07 sec
#  ARIMA(0,1,1)(1,1,1)[12]             : AIC=504.579, Time=0.17 sec
#  ARIMA(0,1,1)(0,1,2)[12]             : AIC=504.436, Time=0.40 sec
#  ARIMA(0,1,1)(1,1,0)[12]             : AIC=504.187, Time=0.15 sec
#  ARIMA(0,1,1)(1,1,2)[12]             : AIC=506.436, Time=0.50 sec
#  ARIMA(0,1,0)(0,1,1)[12]             : AIC=557.817, Time=0.08 sec
#  ARIMA(1,1,1)(0,1,1)[12]             : AIC=505.803, Time=0.21 sec
#  ARIMA(0,1,2)(0,1,1)[12]             : AIC=505.786, Time=0.14 sec
#  ARIMA(1,1,0)(0,1,1)[12]             : AIC=534.056, Time=0.12 sec
#  ARIMA(1,1,2)(0,1,1)[12]             : AIC=507.759, Time=0.29 sec
#  ARIMA(0,1,1)(0,1,1)[12] intercept   : AIC=inf, Time=0.63 sec
#
# Best model:  ARIMA(0,1,1)(0,1,1)[12]
# Total fit time: 5.117 seconds
# c:\Users\yasee\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\rnn\rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 406ms/step
# ✅ Forecasting completed for Nike Dri-FIT Running Shorts!
# 📂 Results saved in: Retail_Store_2/Nike Dri-FIT Running Shorts_forecast_2024_2028.csv
# 📊 Combined sales plot saved as: Retail_Store_2/Nike Dri-FIT Running Shorts_forecast_plot.png
# Processing: Carhartt Duck Chore Coat...
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(1,1,1)[12]             : AIC=274.991, Time=0.49 sec
#  ARIMA(0,1,0)(0,1,0)[12]             : AIC=273.617, Time=0.01 sec
#  ARIMA(1,1,0)(1,1,0)[12]             : AIC=272.038, Time=0.05 sec
#  ARIMA(0,1,1)(0,1,1)[12]             : AIC=267.175, Time=0.09 sec
#  ARIMA(0,1,1)(0,1,0)[12]             : AIC=265.785, Time=0.03 sec
#  ARIMA(0,1,1)(1,1,0)[12]             : AIC=267.118, Time=0.17 sec
#  ARIMA(0,1,1)(1,1,1)[12]             : AIC=269.108, Time=0.15 sec
#  ARIMA(1,1,1)(0,1,0)[12]             : AIC=267.779, Time=0.05 sec
#  ARIMA(0,1,2)(0,1,0)[12]             : AIC=267.779, Time=0.47 sec
#  ARIMA(1,1,0)(0,1,0)[12]             : AIC=270.075, Time=0.02 sec
#  ARIMA(1,1,2)(0,1,0)[12]             : AIC=269.764, Time=0.50 sec
#  ARIMA(0,1,1)(0,1,0)[12] intercept   : AIC=inf, Time=0.94 sec
#
# Best model:  ARIMA(0,1,1)(0,1,0)[12]
# Total fit time: 2.972 seconds
# c:\Users\yasee\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\rnn\rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 402ms/step
# ✅ Forecasting completed for Carhartt Duck Chore Coat!
# 📂 Results saved in: Retail_Store_2/Carhartt Duck Chore Coat_forecast_2024_2028.csv
# 📊 Combined sales plot saved as: Retail_Store_2/Carhartt Duck Chore Coat_forecast_plot.png
# Processing: Patagonia Better Sweater Fleece...
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(1,1,1)[12]             : AIC=inf, Time=2.35 sec
#  ARIMA(0,1,0)(0,1,0)[12]             : AIC=487.265, Time=0.03 sec
#  ARIMA(1,1,0)(1,1,0)[12]             : AIC=411.792, Time=0.64 sec
#  ARIMA(0,1,1)(0,1,1)[12]             : AIC=462.530, Time=0.07 sec
#  ARIMA(1,1,0)(0,1,0)[12]             : AIC=410.605, Time=0.03 sec
#  ARIMA(1,1,0)(0,1,1)[12]             : AIC=411.697, Time=0.14 sec
#  ARIMA(1,1,0)(1,1,1)[12]             : AIC=413.697, Time=0.20 sec
#  ARIMA(2,1,0)(0,1,0)[12]             : AIC=412.604, Time=0.09 sec
#  ARIMA(1,1,1)(0,1,0)[12]             : AIC=412.604, Time=0.06 sec
#  ARIMA(0,1,1)(0,1,0)[12]             : AIC=460.546, Time=0.03 sec
#  ARIMA(2,1,1)(0,1,0)[12]             : AIC=408.896, Time=0.09 sec
#  ARIMA(2,1,1)(1,1,0)[12]             : AIC=409.444, Time=0.29 sec
#  ARIMA(2,1,1)(0,1,1)[12]             : AIC=409.152, Time=0.27 sec
#  ARIMA(2,1,1)(1,1,1)[12]             : AIC=411.151, Time=0.38 sec
#  ARIMA(3,1,1)(0,1,0)[12]             : AIC=393.707, Time=0.31 sec
#  ARIMA(3,1,1)(1,1,0)[12]             : AIC=393.731, Time=0.29 sec
#  ARIMA(3,1,1)(0,1,1)[12]             : AIC=393.728, Time=0.34 sec
#  ARIMA(3,1,1)(1,1,1)[12]             : AIC=395.490, Time=0.50 sec
#  ARIMA(3,1,0)(0,1,0)[12]             : AIC=391.820, Time=0.78 sec
#  ARIMA(3,1,0)(1,1,0)[12]             : AIC=391.976, Time=0.97 sec
#  ARIMA(3,1,0)(0,1,1)[12]             : AIC=392.024, Time=1.86 sec
#  ARIMA(3,1,0)(1,1,1)[12]             : AIC=393.794, Time=0.71 sec
#  ARIMA(4,1,0)(0,1,0)[12]             : AIC=393.636, Time=0.11 sec
#  ARIMA(4,1,1)(0,1,0)[12]             : AIC=395.347, Time=0.27 sec
#  ARIMA(3,1,0)(0,1,0)[12] intercept   : AIC=392.091, Time=0.37 sec
#
# Best model:  ARIMA(3,1,0)(0,1,0)[12]
# Total fit time: 11.205 seconds
# c:\Users\yasee\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# c:\Users\yasee\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\rnn\rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 398ms/step
# ✅ Forecasting completed for Patagonia Better Sweater Fleece!
# 📂 Results saved in: Retail_Store_2/Patagonia Better Sweater Fleece_forecast_2024_2028.csv
# 📊 Combined sales plot saved as: Retail_Store_2/Patagonia Better Sweater Fleece_forecast_plot.png
# Processing: 1984 by George Orwell...
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(1,1,1)[12]             : AIC=inf, Time=3.23 sec
#  ARIMA(0,1,0)(0,1,0)[12]             : AIC=226.750, Time=0.01 sec
#  ARIMA(1,1,0)(1,1,0)[12]             : AIC=212.599, Time=0.08 sec
#  ARIMA(0,1,1)(0,1,1)[12]             : AIC=inf, Time=0.10 sec
#  ARIMA(1,1,0)(0,1,0)[12]             : AIC=220.304, Time=0.02 sec
#  ARIMA(1,1,0)(2,1,0)[12]             : AIC=211.175, Time=0.15 sec
#  ARIMA(1,1,0)(2,1,1)[12]             : AIC=213.058, Time=0.35 sec
#  ARIMA(1,1,0)(1,1,1)[12]             : AIC=212.826, Time=0.11 sec
#  ARIMA(0,1,0)(2,1,0)[12]             : AIC=215.168, Time=0.09 sec
#  ARIMA(2,1,0)(2,1,0)[12]             : AIC=210.915, Time=0.16 sec
#  ARIMA(2,1,0)(1,1,0)[12]             : AIC=211.865, Time=0.60 sec
#  ARIMA(2,1,0)(2,1,1)[12]             : AIC=212.801, Time=0.83 sec
#  ARIMA(2,1,0)(1,1,1)[12]             : AIC=212.251, Time=0.33 sec
#  ARIMA(3,1,0)(2,1,0)[12]             : AIC=211.755, Time=2.09 sec
#  ARIMA(2,1,1)(2,1,0)[12]             : AIC=inf, Time=0.56 sec
#  ARIMA(1,1,1)(2,1,0)[12]             : AIC=inf, Time=0.43 sec
#  ARIMA(3,1,1)(2,1,0)[12]             : AIC=inf, Time=1.74 sec
#  ARIMA(2,1,0)(2,1,0)[12] intercept   : AIC=211.569, Time=0.24 sec
#
# Best model:  ARIMA(2,1,0)(2,1,0)[12]
# Total fit time: 11.134 seconds
# c:\Users\yasee\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:997: UserWarning: Non-stationary starting seasonal autoregressive Using zeros as starting parameters.
#   warn('Non-stationary starting seasonal autoregressive'
# c:\Users\yasee\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\rnn\rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 434ms/step
# ✅ Forecasting completed for 1984 by George Orwell!
# 📂 Results saved in: Retail_Store_2/1984 by George Orwell_forecast_2024_2028.csv
# 📊 Combined sales plot saved as: Retail_Store_2/1984 by George Orwell_forecast_plot.png

# %%
import pandas as pd
import os

# 📂 Define folders
actual_sales_file = "R2.csv"
forecast_folder = "Retail_Store_2"
output_folder = "Retail_Store_2Merged"

# ✅ Create output folder if it doesn't exist
os.makedirs(output_folder, exist_ok=True)

# ✅ Load actual sales data
data = pd.read_csv(actual_sales_file)
data['SaleDate'] = pd.to_datetime(data['SaleDate'], format='%d/%m/%Y')

# ✅ Aggregate actual sales by month
actual_sales = data.groupby(['ProductName', pd.Grouper(key='SaleDate', freq='M')])['QuantitySold'].sum().reset_index()

# 🔹 Get list of all unique products
products = data['ProductName'].unique()

# 🔄 Loop through all products and merge actual & predicted sales
for selected_product in products:
    print(f"Processing: {selected_product}...")

    # ✅ Get actual sales for the product
    product_sales = actual_sales[actual_sales['ProductName'] == selected_product]

    # ✅ Try to load the forecasted sales CSV (Skip if not found)
    forecast_file = os.path.join(forecast_folder, f"{selected_product}_forecast_2024_2028.csv")
    if not os.path.exists(forecast_file):
        print(f"❌ No forecast data found for {selected_product}. Skipping.")
        continue
    
    forecast_data = pd.read_csv(forecast_file)
    forecast_data['Date'] = pd.to_datetime(forecast_data['Date'])

    # ✅ Merge actual and forecasted sales
    combined_sales = pd.concat([
        product_sales.rename(columns={'SaleDate': 'Date', 'QuantitySold': 'Sales'}),
        forecast_data.rename(columns={'Predicted Sales': 'Sales'})
    ])

    # ✅ Save merged sales data
    output_file = os.path.join(output_folder, f"{selected_product}_total_and_forecasted_sales.csv")
    combined_sales.to_csv(output_file, index=False)

    print(f"✅ Saved merged sales data for {selected_product}: {output_file}")
# Out:
# Processing: Nanoleaf Shapes Smart Light Panels...
# ✅ Saved merged sales data for Nanoleaf Shapes Smart Light Panels: Retail_Store_2Merged\Nanoleaf Shapes Smart Light Panels_total_and_forecasted_sales.csv
# Processing: Insta360 X3 Action Camera...
# ✅ Saved merged sales data for Insta360 X3 Action Camera: Retail_Store_2Merged\Insta360 X3 Action Camera_total_and_forecasted_sales.csv
# Processing: Google Pixel Buds Pro...
# ✅ Saved merged sales data for Google Pixel Buds Pro: Retail_Store_2Merged\Google Pixel Buds Pro_total_and_forecasted_sales.csv
# Processing: Ultimate Ears MEGABOOM 3 Speaker...
# ✅ Saved merged sales data for Ultimate Ears MEGABOOM 3 Speaker: Retail_Store_2Merged\Ultimate Ears MEGABOOM 3 Speaker_total_and_forecasted_sales.csv
# Processing: Keurig K-Supreme Plus Coffee Maker...
# ✅ Saved merged sales data for Keurig K-Supreme Plus Coffee Maker: Retail_Store_2Merged\Keurig K-Supreme Plus Coffee Maker_total_and_forecasted_sales.csv
# Processing: Panasonic Lumix GH6 Camera...
# ✅ Saved merged sales data for Panasonic Lumix GH6 Camera: Retail_Store_2Merged\Panasonic Lumix GH6 Camera_total_and_forecasted_sales.csv
# Processing: Philips Wiz Smart LED Bulbs...
# ✅ Saved merged sales data for Philips Wiz Smart LED Bulbs: Retail_Store_2Merged\Philips Wiz Smart LED Bulbs_total_and_forecasted_sales.csv
# Processing: Kobo Clara 2E E-Reader...
# ✅ Saved merged sales data for Kobo Clara 2E E-Reader: Retail_Store_2Merged\Kobo Clara 2E E-Reader_total_and_forecasted_sales.csv
# Processing: De'Longhi Dinamica Espresso Machine...
# ✅ Saved merged sales data for De'Longhi Dinamica Espresso Machine: Retail_Store_2Merged\De'Longhi Dinamica Espresso Machine_total_and_forecasted_sales.csv
# Processing: Valve Steam Deck Handheld...
# ✅ Saved merged sales data for Valve Steam Deck Handheld: Retail_Store_2Merged\Valve Steam Deck Handheld_total_and_forecasted_sales.csv
# Processing: Garmin Forerunner 965...
# ✅ Saved merged sales data for Garmin Forerunner 965: Retail_Store_2Merged\Garmin Forerunner 965_total_and_forecasted_sales.csv
# Processing: Shark FlexStyle Air Styling System...
# ✅ Saved merged sales data for Shark FlexStyle Air Styling System: Retail_Store_2Merged\Shark FlexStyle Air Styling System_total_and_forecasted_sales.csv
# Processing: Acer Swift Edge 16 Laptop...
# ✅ Saved merged sales data for Acer Swift Edge 16 Laptop: Retail_Store_2Merged\Acer Swift Edge 16 Laptop_total_and_forecasted_sales.csv
# Processing: Arlo Pro 5S 2K Security Camera...
# ✅ Saved merged sales data for Arlo Pro 5S 2K Security Camera: Retail_Store_2Merged\Arlo Pro 5S 2K Security Camera_total_and_forecasted_sales.csv
# Processing: Cuisinart Precision Stand Mixer...
# ✅ Saved merged sales data for Cuisinart Precision Stand Mixer: Retail_Store_2Merged\Cuisinart Precision Stand Mixer_total_and_forecasted_sales.csv
# Processing: Honeywell Home T9 Smart Thermostat...
# ✅ Saved merged sales data for Honeywell Home T9 Smart Thermostat: Retail_Store_2Merged\Honeywell Home T9 Smart Thermostat_total_and_forecasted_sales.csv
# Processing: Roborock S7 MaxV Ultra Vacuum...
# ✅ Saved merged sales data for Roborock S7 MaxV Ultra Vacuum: Retail_Store_2Merged\Roborock S7 MaxV Ultra Vacuum_total_and_forecasted_sales.csv
# Processing: Polar Grit X Pro Smartwatch...
# ✅ Saved merged sales data for Polar Grit X Pro Smartwatch: Retail_Store_2Merged\Polar Grit X Pro Smartwatch_total_and_forecasted_sales.csv
# Processing: Razer DeathAdder V3 Mouse...
# ✅ Saved merged sales data for Razer DeathAdder V3 Mouse: Retail_Store_2Merged\Razer DeathAdder V3 Mouse_total_and_forecasted_sales.csv
# Processing: HP Spectre x360 14 Laptop...
# ✅ Saved merged sales data for HP Spectre x360 14 Laptop: Retail_Store_2Merged\HP Spectre x360 14 Laptop_total_and_forecasted_sales.csv
# Processing: The Brothers Karamazov...
# ✅ Saved merged sales data for The Brothers Karamazov: Retail_Store_2Merged\The Brothers Karamazov_total_and_forecasted_sales.csv
# Processing: Ninja Foodi 9-in-1 Cooker...
# ✅ Saved merged sales data for Ninja Foodi 9-in-1 Cooker: Retail_Store_2Merged\Ninja Foodi 9-in-1 Cooker_total_and_forecasted_sales.csv
# Processing: Bowers & Wilkins PX7 S2 Headphones...
# ✅ Saved merged sales data for Bowers & Wilkins PX7 S2 Headphones: Retail_Store_2Merged\Bowers & Wilkins PX7 S2 Headphones_total_and_forecasted_sales.csv
# Processing: Brave New World...
# ✅ Saved merged sales data for Brave New World: Retail_Store_2Merged\Brave New World_total_and_forecasted_sales.csv
# Processing: Pride and Prejudice...
# ✅ Saved merged sales data for Pride and Prejudice: Retail_Store_2Merged\Pride and Prejudice_total_and_forecasted_sales.csv
# Processing: To Kill a Mockingbird...
# ✅ Saved merged sales data for To Kill a Mockingbird: Retail_Store_2Merged\To Kill a Mockingbird_total_and_forecasted_sales.csv
# Processing: The Lord of the Rings...
# ✅ Saved merged sales data for The Lord of the Rings: Retail_Store_2Merged\The Lord of the Rings_total_and_forecasted_sales.csv
# Processing: Crime and Punishment...
# ✅ Saved merged sales data for Crime and Punishment: Retail_Store_2Merged\Crime and Punishment_total_and_forecasted_sales.csv
# Processing: Levi’s 501 Original Fit Jeans...
# ✅ Saved merged sales data for Levi’s 501 Original Fit Jeans: Retail_Store_2Merged\Levi’s 501 Original Fit Jeans_total_and_forecasted_sales.csv
# Processing: Hanes Crewneck T-Shirts...
# ✅ Saved merged sales data for Hanes Crewneck T-Shirts: Retail_Store_2Merged\Hanes Crewneck T-Shirts_total_and_forecasted_sales.csv
# Processing: The Catcher in the Rye...
# ✅ Saved merged sales data for The Catcher in the Rye: Retail_Store_2Merged\The Catcher in the Rye_total_and_forecasted_sales.csv
# Processing: Moby-Dick...
# ✅ Saved merged sales data for Moby-Dick: Retail_Store_2Merged\Moby-Dick_total_and_forecasted_sales.csv
# Processing: War and Peace...
# ✅ Saved merged sales data for War and Peace: Retail_Store_2Merged\War and Peace_total_and_forecasted_sales.csv
# Processing: Fahrenheit 451...
# ✅ Saved merged sales data for Fahrenheit 451: Retail_Store_2Merged\Fahrenheit 451_total_and_forecasted_sales.csv
# Processing: Under Armour HeatGear Compression Shirt...
# ✅ Saved merged sales data for Under Armour HeatGear Compression Shirt: Retail_Store_2Merged\Under Armour HeatGear Compression Shirt_total_and_forecasted_sales.csv
# Processing: The Great Gatsby...
# ✅ Saved merged sales data for The Great Gatsby: Retail_Store_2Merged\The Great Gatsby_total_and_forecasted_sales.csv
# Processing: Nike Dri-FIT Running Shorts...
# ✅ Saved merged sales data for Nike Dri-FIT Running Shorts: Retail_Store_2Merged\Nike Dri-FIT Running Shorts_total_and_forecasted_sales.csv
# Processing: Carhartt Duck Chore Coat...
# ✅ Saved merged sales data for Carhartt Duck Chore Coat: Retail_Store_2Merged\Carhartt Duck Chore Coat_total_and_forecasted_sales.csv
# Processing: Patagonia Better Sweater Fleece...
# ✅ Saved merged sales data for Patagonia Better Sweater Fleece: Retail_Store_2Merged\Patagonia Better Sweater Fleece_total_and_forecasted_sales.csv
# Processing: 1984 by George Orwell...
# ✅ Saved merged sales data for 1984 by George Orwell: Retail_Store_2Merged\1984 by George Orwell_total_and_forecasted_sales.csv

# %%
import pandas as pd
import os

# 📂 Define the folder containing merged sales data
merged_folder = "Retail_Store_2Merged"
output_file = "ALLRetail_Store_2.xlsx"

# ✅ Get list of all merged sales files
merged_files = [f for f in os.listdir(merged_folder) if f.endswith("_total_and_forecasted_sales.csv")]

# ✅ Read and combine all merged sales data
all_sales_data = []

for file in merged_files:
    product_name = file.replace("_total_and_forecasted_sales.csv", "")  # Extract product name
    file_path = os.path.join(merged_folder, file)
    
    # Load sales data
    df = pd.read_csv(file_path)
    df['Date'] = pd.to_datetime(df['Date'])
    df['ProductName'] = product_name  # Add product name column
    
    all_sales_data.append(df)

# ✅ Combine all products into a single DataFrame
merged_sales_df = pd.concat(all_sales_data, ignore_index=True)

# ✅ Save all product sales in **one Excel file**
merged_sales_df.to_excel(output_file, index=False, sheet_name="Sales_Data")

print(f"✅ All product sales saved in: {output_file}")

# ✅ Display first few rows to verify
print(merged_sales_df.head())
# Out:
# ✅ All product sales saved in: ALLRetail_Store_2.xlsx
#              ProductName       Date  Sales
# 0  1984 by George Orwell 2015-05-31      2
# 1  1984 by George Orwell 2017-12-31     13
# 2  1984 by George Orwell 2019-07-31     12
# 3  1984 by George Orwell 2019-08-31      4
# 4  1984 by George Orwell 2019-09-30      6
